# %% [markdown]
# ## Baseline
#
# Includes calculating the mean of the each part in `Train` and apply that to the `Dev`

# %%
import os
import sys

import pandas as pd

# %%
sys.path.append(os.path.abspath('..'))

from src.metrics import evaluate

df = pd.read_parquet('../data/processed/merged.parquet')
df.shape
# Out:
# (15170, 6)

# %%
train_df = df[df['split'] == 'train']
dev_df = df[df['split'] == 'dev']

train_df.shape, dev_df.shape
# Out:
# ((12218, 6), (1752, 6))

# %%
train_means = train_df.groupby('part')["score"].mean()

dev_df['y_true'] = dev_df['score']
dev_df['y_pred'] = dev_df['part'].map(train_means)

dev_df.head()
# Out:
# C:\Users\CBABM\AppData\Local\Temp\ipykernel_11588\1107152803.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_df['y_true'] = dev_df['score']
# C:\Users\CBABM\AppData\Local\Temp\ipykernel_11588\1107152803.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_df['y_pred'] = dev_df['part'].map(train_means)
#   submission_id  score split part  score_overall  \
# 0  SI114J-00011    5.0   dev   P1          5.250
# 1  SI114J-00045    4.0   dev   P1          3.750
# 2  SI114J-00057    3.5   dev   P1          3.625
# 3  SI114J-00116    3.0   dev   P1          3.375
# 4  SI114J-00139    4.0   dev   P1          3.500
#
#                                          audio_files  y_true    y_pred
# 0  [ml\data\raw\data\dev\dev01\SI114J-00011-P1000...     5.0  3.953064
# 1  [ml\data\raw\data\dev\dev01\SI114J-00045-P1000...     4.0  3.953064
# 2  [ml\data\raw\data\dev\dev01\SI114J-00057-P1000...     3.5  3.953064
# 3  [ml\data\raw\data\dev\dev02\SI114J-00116-P1000...     3.0  3.953064
# 4  [ml\data\raw\data\dev\dev02\SI114J-00139-P1000...     4.0  3.953064

# %%
evaluate(dev_df)
# Out:
# c:\work_dir\SpeakTrace\ml\src\metrics.py:43: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return float(stats.pearsonr(t, p).statistic)
# c:\work_dir\SpeakTrace\ml\src\metrics.py:51: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return float(stats.spearmanr(t, p).statistic)
# c:\work_dir\SpeakTrace\ml\src\metrics.py:43: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return float(stats.pearsonr(t, p).statistic)
# c:\work_dir\SpeakTrace\ml\src\metrics.py:51: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return float(stats.spearmanr(t, p).statistic)
# c:\work_dir\SpeakTrace\ml\src\metrics.py:43: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return float(stats.pearsonr(t, p).statistic)
# c:\work_dir\SpeakTrace\ml\src\metrics.py:51: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return float(stats.spearmanr(t, p).statistic)
# c:\work_dir\SpeakTrace\ml\src\metrics.py:43: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return float(stats.pearsonr(t, p).statistic)
# c:\work_dir\SpeakTrace\ml\src\metrics.py:51: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return float(stats.spearmanr(t, p).statistic)
# c:\work_dir\SpeakTrace\ml\src\metrics.py:43: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return float(stats.pearsonr(t, p).statistic)
# c:\work_dir\SpeakTrace\ml\src\metrics.py:51: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return float(stats.spearmanr(t, p).statistic)
# {'overall': {'n': 438,
#   'rmse': 0.6706282188887615,
#   'mae': 0.547749904556538,
#   'bias': 0.06564548891637635,
#   'pearson': nan,
#   'spearman': nan,
#   'within_0.5': 50.456621004566216,
#   'within_1.0': 86.98630136986301},
#  'parts': {'n': 1752,
#   'rmse': 0.750704466306593,
#   'mae': 0.6065092078516956,
#   'bias': 0.06564548891637648,
#   'pearson': 0.08924836303101745,
#   'spearman': 0.06943805327588246,
#   'within_0.5': 46.97488584474886,
#   'within_1.0': 81.39269406392694},
#  'P1': {'n': 438,
#   'rmse': 0.787001514020658,
#   'mae': 0.6266468420519964,
#   'bias': 0.1094565793312022,
#   'pearson': nan,
#   'spearman': nan,
#   'within_0.5': 47.03196347031963,
#   'within_1.0': 78.99543378995433},
#  'P3': {'n': 438,
#   'rmse': 0.7381396824450298,
#   'mae': 0.5983152774047215,
#   'bias': 0.104798997224461,
#   'pearson': nan,
#   'spearman': nan,
#   'within_0.5': 47.94520547945205,
#   'within_1.0': 82.1917808219178},
#  'P4': {'n': 438,
#   'rmse': 0.7266660937716639,
#   'mae': 0.5891033969259758,
#   'bias': -0.002281585485378026,
#   'pearson': nan,
#   'spearman': nan,
#   'within_0.5': 49.54337899543379,
#   'within_1.0': 82.1917808219178},
#  'P5': {'n': 438,
#   'rmse': 0.7496423128548979,
#   'mae': 0.6119713150240892,
#   'bias': 0.05060796459522079,
#   'pearson': nan,
#   'spearman': nan,
#   'within_0.5': 43.37899543378995,
#   'within_1.0': 82.1917808219178}}
